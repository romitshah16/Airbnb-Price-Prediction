# %% [markdown]
# # Airbnb Price Prediction
#
#
# In project we will scrape AirBnb and organize the information in a Pandas dataframe. In Part 2, we will use linear regression to gain meaningful insights.

# %% [markdown]
# #### Background and Motivation
#
# Airbnb is a trusted community and peer-to-peer online marketplace and homestay network for people to list, book or rent short-term lodging in residential properties, with the cost of such accommodation set by the property owner. The company has over 4 million lodging listings in 65,000 cities and 191 countries and has facilitated over 260 million check-ins. Once the account is setup, the hosts can use the site free of charge for all services.
# They can list their space, specify the details of the room or home etc, location, pricing per night, write an overview of the space, add photos clicked by themselves or a team of professional photographers sent by Airbnb and how many people they are willing to accommodate. The guests can easily search location, check in and checkout dates, specify their requirements as well as compare pricing and choose their affordable price range.
# Guests can also make a request to the host easily without any concerns or questions asked. All users can write as well as receive reviews. All 3 of us are new to Salt Lake City and want to explore new destinations. While on a trip Airbnb houses are the best to stay.As students we want to make sure that we get the best deal on Airbnb. This motivated us to choose
# this project , this way we will be able to get the best deal for every trip.
# We can see great potential here with dataset, features, analysis, predictions, visualizations and feedback. We
# have chosen Airbnb for the very reason that it is inclined to the techniques and analysis we have learnt in the
# Data Science class.

# %% [markdown]
# #### Project Objectives
# Primary questions we are trying to answers are:
# 1) How many of their listings are there in my city? (if you check a simple search will never list more than 300
# results at a time)
# 2) What is the price distribution based on location?
# 3) Do lots of people leave reviews?
# 4)Determining the right location for the investors
# 5) Key Word search , for the host which will help the hosts to determine what are the views of the guest about their property. 6) For the hosts, we can predict the price of the house based on other listings in that area.

# %% [markdown]
# ## Your Data
# First Name:Arpita, Romit, Dhaval
# <br>
# Last Name:Bangera, Shah, Swali
# <br>
# E-mail:arpita.bangera@utah.edu, romit.shah@utah.edu, u1166579@utah.edu
# <br>
# UID:u1147354, u1147369,u1166579
# <br>
# Video link: https://www.youtube.com/watch?v=mDBA_PQRH1E&feature=youtu.be

# %%
# imports and setup 
from bs4 import BeautifulSoup
# you can use either of these libraries to get html from a website
import requests
import urllib.request


import pandas as pd
import scipy as sc
import numpy as np
import seaborn as sns
import statsmodels.formula.api as sm

import matplotlib.pyplot as plt 
plt.style.use('ggplot')
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (10, 6)

# %%
## Your code goes here
import urllib.request
from selenium import webdriver
import pandas as pd
import numpy as np
import requests
import urllib.request
import scipy as sc
from lxml import html
import statsmodels.formula.api as sm

import matplotlib.pyplot as plt 
plt.style.use('ggplot')
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (10, 6) 
from bs4 import BeautifulSoup
name=[]
import time
soup=[]

# %%
soup=[]
driver=webdriver.Firefox()
for i in range(0,18):
    url="https://www.airbnb.com/s/Utah--UT--United-States/homes?section_offset=%s"%i
    driver.get(url)
    time.sleep(10)
    html=driver.execute_script("return document.documentElement.outerHTML")
    soup.append(BeautifulSoup(html,"html.parser"))

#total number of pages    
print(len(soup))
# Out:
# 18

# %% [markdown]
# #### Data Scraping of the first page. We have total 18 pages.

# %%
name_of_houses=[]
url_list=[]
url_prefix="https://www.airbnb.com"
ratings=[]
stars=[]

#for nstars in soupTwo[i].find_all(class_="_q27mtmr"):
#        for number_of_star in nstars.findAll("span", {'class':"_19olcgv7"}):
#            stars.append(number_of_star.get_text())
for i in range(len(soup)):
    for names in soup[i].find_all(class_="_f21qs6"):
        name_of_houses.append(names.find("a").get_text())
        url_list.append(url_prefix+names.find("a").get("href"))
        if names.find_all(class_="_q27mtmr"):
            for rating in names.find_all(class_="_q27mtmr"):
                ratings.append(rating.find("span").get("aria-label"))
        else:
                ratings.append(np.nan)
        #print(rating)
        #"stars.append(names.find("span",{"class":"_q27mtmr"}))
for star in ratings:
    if type(star) != float:
        stars.append(star.split(" ")[1])
    else:
        stars.append(np.nan)
print(stars)
print(len(stars))
# Out:
# ['5', '5', nan, '5', '5', '5', '4.5', '5', '5', '5', '5', '5', '5', '5', '4.5', '5', '5', '5', '5', '5', '5', '5', nan, '5', '4.5', '5', nan, '5', '5', nan, '4.5', '5', '5', '5', '5', '5', '5', '4.5', '5', '5', '5', nan, '5', '5', '4.5', '5', '4.5', '5', '5', nan, '5', '5', '5', '5', nan, '5', '5', nan, '5', '5', '5', '5', nan, '5', '5', nan, '5', '5', '5', '5', '5', nan, nan, nan, '4', nan, '5', nan, '5', '5', nan, '5', '5', '4.5', '5', '5', '4.5', nan, '5', '5', nan, '5', '5', nan, nan, nan, '4', nan, nan, '5', '5', '5', '4.5', '5', '4.5', '5', '5', '5', '5', nan, nan, nan, nan, '5', nan, nan, '5', '5', '4.5', nan, '5', '4.5', nan, '5', nan, nan, nan, nan, '5', '5', '5', nan, '4.5', nan, nan, '5', '5', '4.5', nan, nan, nan, '3.5', '5', '5', nan, '5', '5', '5', '5', nan, nan, '5', '5', '5', nan, '5', '5', '5', '5', nan, '5', '4.5', '5', '5', '5', '4.5', '5', nan, '5', nan, '5', '5', nan, '5', '5', '4.5', '5', '5', '5', '5', '5', '5', nan, nan, nan, '5', nan, nan, '5', nan, '5', nan,
# ...

# %%
#Cleaning the price and converting it into float

price=[]
a=[]
for q in range(len(soup)):
    j=soup[q].find_all(class_="_hylizj6")
    a.append(j)
    for i in range(len(j)):
        price.append(j[i].get_text())
p=[]
for i in range(len(price)):
     if 'Price' in price[i]:
            a=price[i].split('$')[1]
            p.append(float(a))

# %%
#visiting each individual listing on each page
driver=webdriver.Firefox()

# %% [markdown]
# # Data Scraping going inside each links and storing them in soup.

# %%
no_of_guests=[]
no_of_bedrooms=[]
no_of_beds=[]
no_of_baths=[]
first_list=[]
waste_list=[]
no_reviews=[]
reviews=[]
amenities=[]
location=[]
another=[]
re=[]
price=[]

for i in range(len(url_list)):
    soupTwo=[]
    url=url_list[i]
    driver.get(url)
    #time.sleep(10)
    html=driver.execute_script("return document.documentElement.outerHTML")
    soupTwo=BeautifulSoup(html,"html.parser")
    #for i in range(0,1):

    for listing in soupTwo.find_all(class_="_1thk0tsb"):
        for l in listing.findAll("span",{'class':"_y8ard79"}):
            first_list.append(l.get_text())
    for listing2 in soupTwo.find_all(id="reviews"):
        reviews=[]
        for l in listing2.findAll(class_="_m7iebup"):
            reviews.append(l.get_text())
        re.append(reviews)
        for r in listing2.find_all(class_="_1vbkutid"):
            no_reviews.append(r.span.get_text())
    for listing3 in soupTwo.find_all(class_="_iq8x9is"):
        for l in listing3.findAll(class_="_m7iebup"):
            amenities.append(l.get_text())
    if soupTwo.find_all(class_="_1xw8gzmn"):
        for listing4 in soupTwo.find_all(class_="_1xw8gzmn"):
            if listing4.find_all(class_="_m7iebup"):
                for l in listing4.findAll(class_="_m7iebup"):
                    location.append(l.get_text())
            else:
                location.append("location not found in class _m7iebup")
    else:
        location.append("location not found in class _1xw8gzmn")
    for listing5 in soupTwo.find_all(class_="_36rlri"):
        for l in listing3.findAll(class_="_10cqp947"):
            price.append(l.span.get_text())

    no_of_guests.append(first_list[0])
    no_of_bedrooms.append(first_list[1])
    no_of_beds.append(first_list[2])
    no_of_baths.append(first_list[3])
    first_list.clear()

# %% [markdown]
# # Creating pandas Dataframe with the data scrapped.

# %%
df=pd.DataFrame({"Name of Property":name_of_houses,
                 "Stars":stars,
                "No of Guests":no_of_guests,
                "No of bedrooms":no_of_bedrooms,
                "No of Beds":no_of_beds,
                "No of Baths":no_of_baths,
                "No of Reviews":no_reviews,
                "Reviews in Text":re,
                 "Location":location,
                 "Price":p
                })

df.tail()
# Out:
#            Location                              Name of Property  \
# 319           Provo                             Comfortable couch
# 320            Orem                Nice and Quiet Private Bedroom
# 321        Highland           Family friendly home away from home
# 322           Provo  Spacious 5 bedroom Provo home near BYU & MTC
# 323  Pleasant Grove     1950s Retro Basement Studio w/Kitchenette
#
#           No of Baths No of Beds No of Guests No of Reviews No of bedrooms  \
# 319            1 bath      1 bed      1 guest     6 Reviews      1 bedroom
# 320  1.5 shared baths      1 bed      1 guest      1 Review      1 bedroom
# 321    1 private bath     3 beds     5 guests     5 Reviews     2 bedrooms
# 322         2.5 baths    11 beds    10 guests     4 Reviews     5 bedrooms
# 323            1 bath     2 beds     3 guests    18 Reviews         Studio
#
#      Price                                    Reviews in Text Stars
# ...

# %%
df.head()
# Out:
#          Location                                Name of Property  \
# 0  Woodland Hills  Mountain Log Home getaway with amazing views!!
# 1          Payson       Two private bedrooms in cozy modern condo
# 2           Provo     Private Master Suite near park and downtown
# 3            Orem                         King Bed near BYU & UVU
# 4           Provo                House on the hill. Near BYU, UVU
#
#          No of Baths No of Beds No of Guests No of Reviews No of bedrooms  \
# 0     1 private bath     2 beds     3 guests    56 Reviews      1 bedroom
# 1     1 private bath     3 beds     4 guests     6 Reviews     2 bedrooms
# 2     1 private bath      1 bed     4 guests    56 Reviews      1 bedroom
# 3      1 shared bath      1 bed     2 guests    95 Reviews      1 bedroom
# 4  1.5 private baths     2 beds     3 guests    72 Reviews     2 bedrooms
#
#    Price                                    Reviews in Text Stars
# ...

# %%
df.describe()
# Out:
#         NoOfBaths    NoOfBeds  NoOfGuests  NoOfReviews  NoOfbedrooms  \
# count  324.000000  324.000000  324.000000   324.000000    324.000000
# mean     1.405864    2.922840    5.040123    21.435185      1.975309
# std      0.687975    2.305647    3.348896    28.062493      1.256318
# min      1.000000    1.000000    1.000000     0.000000      0.000000
# 25%      1.000000    1.000000    2.000000     4.000000      1.000000
# 50%      1.000000    2.000000    4.000000    11.000000      2.000000
# 75%      2.000000    4.000000    6.000000    26.000000      3.000000
# max      4.500000   14.000000   16.000000   178.000000      8.000000
#
#             Price       Stars
# count  324.000000  324.000000
# mean    66.561728    4.844136
# std     46.745201    0.241761
# min     15.000000    4.000000
# 25%     32.000000    4.500000
# 50%     55.000000    5.000000
# 75%     87.250000    5.000000
# max    344.000000    5.000000

# %% [markdown]
# # Data Cleaning

# %%
# Extract Numeric Ratings from No of Reviews
for rows in range(len(df["No of Reviews"])):
    if "No" in df["No of Reviews"][rows]:
        df["No of Reviews"][rows]=0
    else:
        a=df["No of Reviews"][rows].split(" ")
        df["No of Reviews"][rows]=a[0]
# Out:
# C:\Users\arpih\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\arpih\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# Extract numeric data from No of Baths
for rows in range(len(df["No of Baths"])):
    a=df["No of Baths"][rows].split(" ")
    df["No of Baths"][rows]=a[0]
# Extract numeric data from No of Beds
for rows in range(len(df["No of Beds"])):
    a=df["No of Beds"][rows].split(" ")
    df["No of Beds"][rows]=a[0]
# Extract numeric data from No of Guests
for rows in range(len(df["No of Guests"])):
    a=df["No of Guests"][rows].split(" ")
    df["No of Guests"][rows]=a[0]

# Extract numeric data from No of bedrooms
for rows in range(len(df["No of bedrooms"])):
    a=df["No of bedrooms"][rows].split(" ")
    if a[0]== 'Studio':
         df["No of bedrooms"][rows]=0
    else:       
        df["No of bedrooms"][rows]=a[0]
# Out:
# C:\Users\arpih\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\arpih\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\arpih\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# ...

# %%
#Converting all the columns to relevant data type 
df["No of bedrooms"]= df["No of bedrooms"].astype('int64')
df["No of Baths"]=df["No of Baths"].astype('float')
df["No of Guests"]=df["No of Guests"].astype('int64')
df["No of Beds"]=df["No of Beds"].astype('int64')
df["Stars"]=df["Stars"].astype('float')
df["No of Reviews"]=df["No of Reviews"].astype('int64')

# %%
df.dtypes
# Out:
# Location             object
# Name of Property     object
# No of Baths         float64
# No of Beds            int64
# No of Guests          int64
# No of Reviews         int64
# No of bedrooms        int64
# Price               float64
# Reviews in Text      object
# Stars               float64
# dtype: object

# %%
#finding null values in dataframe- No Null values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %% [markdown]
# #### The above heatmap shows that Stars variable has a lot of null values. We will convert them into a numeric value.

# %%
#Converting all NaN to 4.5
df["Stars"] = df["Stars"].fillna(4.5).astype(float)

# %%
df.tail()
# Out:
#            Location                              Name of Property  \
# 319           Provo                             Comfortable couch
# 320            Orem                Nice and Quiet Private Bedroom
# 321        Highland           Family friendly home away from home
# 322           Provo  Spacious 5 bedroom Provo home near BYU & MTC
# 323  Pleasant Grove     1950s Retro Basement Studio w/Kitchenette
#
#      No of Baths  No of Beds  No of Guests  No of Reviews  No of bedrooms  \
# 319          1.0           1             1              6               1
# 320          1.5           1             1              1               1
# 321          1.0           3             5              5               2
# 322          2.5          11            10              4               5
# 323          1.0           2             3             18               0
#
#      Price                                    Reviews in Text  Stars
# ...

# %%
df.to_csv("Airbnb_proj.csv")

# %%
df["Location"].nunique()
# Out:
# 21

# %%
df.rename(columns={'No of Baths': 'NoOfBaths', 'No of Beds': 'NoOfBeds','No of Guests':'NoOfGuests','No of Reviews':'NoOfReviews','No of bedrooms':'NoOfbedrooms' }, inplace=True)
df.head()
# Out:
#          Location                                Name of Property  NoOfBaths  \
# 0  Woodland Hills  Mountain Log Home getaway with amazing views!!        1.0
# 1          Payson       Two private bedrooms in cozy modern condo        1.0
# 2           Provo     Private Master Suite near park and downtown        1.0
# 3            Orem                         King Bed near BYU & UVU        1.0
# 4           Provo                House on the hill. Near BYU, UVU        1.5
#
#    NoOfBeds  NoOfGuests  NoOfReviews  NoOfbedrooms  Price  \
# 0         2           3           56             1   28.0
# 1         3           4            6             2   25.0
# 2         1           4           56             1   22.0
# 3         1           2           95             1   25.0
# 4         2           3           72             2   30.0
#
#                                      Reviews in Text  Stars
# 0  [This place is a steal! Extremely comfortable ...    5.0
# ...

# %%
sns.countplot(x="Stars",data=df)

# %% [markdown]
# #### The countplot above tells us that most of the ratings have received 5 stars followed by 4.5 stars and then 4 stars. This is great from customer as well as host perspective. It means that the customers had a wonderful experience thereby giving out 5 stars. These ratings help the hosts create good value for their place.

# %%
sns.countplot(x="NoOfbedrooms",data=df,hue="Stars")

# %% [markdown]
# #### This is an interesting countplot which gives very informational observation. People who have hosted 1 bedroom have received the highest number of rating. This means major business has been done with 1 bedroom only.

# %%
sns.pairplot(df[["Stars","NoOfGuests","NoOfbedrooms","NoOfBeds","NoOfBaths","NoOfReviews","Price"]])

# %% [markdown]
# #### A pairplot is a very nice way to check the relationship between variables with each other. In our case above, we can see there is a good enough relationship between price and NoOfGuests, NoOfbedrooms, and NoOfBeds.

# %%
#Distribution of Price in Salt Lake City
sns.distplot(df["Price"])
plt.tight_layout()

# %% [markdown]
# #### The distribution plot above shows that we have majority of the apartments priced between 0 and 100 dollars.

# %%
sns.lmplot("NoOfbedrooms","Price", data=df, hue="Stars")

# %% [markdown]
# #### A regression plot shows a relationship between two variables. Here, we have plotted a relationship between Price and NoOfGuests by setting the hue as Stars. We can see that these two variables have good linear relationship but there are some outliers too.

# %%
corr=df.corr()
sns.heatmap(corr,annot=True)

# %% [markdown]
# #### A heatmap is a very nice visualization technique to display the correlation between the variables with each other. From above results we can see that Price does not have a good correlation with any other variables.

# %%
# to show the average/ sum price based on location
print(df.groupby("Location")["Price"].sum())
df.groupby("Location")["Price"].sum().plot.bar()
# Out:
# Location
# Alpine                39.0
# American Fork        469.0
# Cedar Hills           28.0
# Eagle Mountain        31.0
# Highland             201.0
# Lehi                 247.0
# Lindon               730.0
# Mapleton             613.0
# Orem                4619.0
# Orem, Utah, US        60.0
# Payson               487.0
# Pleasant Grove      1051.0
# Provo               8654.0
# Salem                 69.0
# Santaquin             70.0
# Saratoga Springs     199.0
# Spanish Fork         794.0
# Springville          506.0
# Sundance             195.0
# Vineyard            2476.0
# Woodland Hills        28.0
# Name: Price, dtype: float64

# %% [markdown]
# #### A barplot of Price Vs Location shows that Provo has the highest priced place. On the contrary, Cedar hills and Woodland has the lowest priced place.

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(df,hue="NoOfbedrooms",palette='Set1',size=6,aspect=2)
g = g.map(plt.hist,'Price',bins=20,alpha=0.7)
plt.legend()

# %% [markdown]
# #### From the above facet grid, we can see majority of house price ranges between 10 to 200 dollars approximately in Utah. Also, majority of 1,2 and 3 bedrooms apartments are sold under 150 dollars

# %%
# Running a linear regression model with target variable as Price and other variables as predictors
lm_model = sm.ols(formula="Price ~ NoOfBaths + NoOfBeds + NoOfGuests + NoOfReviews + NoOfbedrooms + Stars", data=df).fit()
lm_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.605
# Model:                            OLS   Adj. R-squared:                  0.597
# Method:                 Least Squares   F-statistic:                     80.83
# Date:                Wed, 18 Apr 2018   Prob (F-statistic):           6.09e-61
# Time:                        22:37:31   Log-Likelihood:                -1554.6
# No. Observations:                 324   AIC:                             3123.
# Df Residuals:                     317   BIC:                             3150.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### R-squared value of a good regression model should be ideally greater than 0.8 but as we can see from above results that the R-squared value is 0.605 which is not considered great for this model. So we would consider this as a fair model.

# %% [markdown]
# # Using Train Test Split apply Linear Regression on our dataframe

# %%
from sklearn.model_selection import train_test_split
final_df=df.drop(["Location","Name of Property","Reviews in Text"],axis=1)

# %%
X=final_df.drop("Price",axis=1)
y=final_df["Price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm= LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0,0.5,'Predicted Y')

# %% [markdown]
# #### The scatter plot shows there is a fair enough linear relationship between the actual and predicted values.

# %%
# calculate these metrics by hand!
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 20.6975165178
# MSE: 913.164904431
# RMSE: 30.2186185063

# %% [markdown]
# #### Scatter plot shows that our predictions are good enough as they show a linear relationship. Also, the MAE and RMSE error values are low which means that the accuracy is pretty good.

# %%
sns.distplot(y_test,bins=50);

# %%
sns.distplot((predictions),bins=50);

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#               Coeffecient
# NoOfBaths        7.248431
# NoOfBeds         3.478944
# NoOfGuests       1.280722
# NoOfReviews     -0.114001
# NoOfbedrooms    15.211925
# Stars            5.333585

# %% [markdown]
# #### Holding all other features fixed, a 1 unit increase in No Of Baths is associated with an increase of 7.24 total dollars in Price of the Apartment. Holding all other features fixed, a 1 unit increase in No of Beds is associated with an increase of 3.47 total dollars in Price of the Apartment. Holding all other features fixed, a 1 unit increase in No of Guests is associated with an increase of 1.28 total dollars  in Price of the Apartment. Holding all other features fixed, a 1 unit increase in NoOfReviews is not that much associated with Price. Holding all other features fixed, a 1 unit increase in NoOfbedrooms is associated with an increase of 15.21 total dollars  in Price of the Apartment. Holding all other features fixed, a 1 unit increase in Stars is associated with an increase of 5.33 total dollars  in Price of the Apartment.
